# %% [markdown]
# ### Packages

# %%
import numpy as np
import csv
import string
import collections
import random

# %% [markdown]
# ### Functions

# %%
def load_data(file):
    X_raw = []
    y = []

    with open(file, 'rt', encoding='utf8') as f:
        dict_reader = csv.DictReader(f)

        for observation in dict_reader:
            y.append(observation['gross_profit'])
            observation.pop('gross_profit', None)

            for key in ['store','month', 'longitude', 'latitude', 'city', 'county', 'bottles', 'pop_city', 'fips', 'pop_county']:
                observation.pop(key, None)

            X_raw.append(observation)

    return X_raw, y

def convert_X_raw_to_array(X_raw):
    feature_keys = list(X_raw[0].keys())
    X = []

    for obs in X_raw:
        row = []

        for key in feature_keys:
            value = obs[key]
            row.append(value)

        X.append(row)

    return np.array(X)

def train_test_valid_split(X, y):
    random.seed(32)

    X_train = []
    X_test = []
    X_valid = []
    y_train = []
    y_test = []
    y_valid = []

    for index in range(len(X)):
        z = random.uniform(0, 1)

        if z < 0.7:
          X_train.append(X[index])
          y_train.append(y[index])

        elif z < 0.85:
            X_test.append(X[index])
            y_test.append(y[index])

        else:
            X_valid.append(X[index])
            y_valid.append(y[index])
                
    X_train = np.array(X_train, dtype=float)
    y_train = np.array(y_train, dtype=float)
    X_test = np.array(X_test, dtype=float)
    y_test = np.array(y_test, dtype=float)
    X_valid = np.array(X_valid, dtype=float)
    y_valid = np.array(y_valid, dtype=float)

    return X_train, X_test, X_valid, y_train, y_test, y_valid

def add_ones(X):
  beta_zero_column = np.ones((X.shape[0], 1))
  X_ones = np.hstack((beta_zero_column, X))

  return X_ones

def ols(X, y):
    X = X.astype(float)
    y = y.astype(float)

    # delete zero rows
    X = X[~np.all(X == 0, axis=1)]

    # delete zero columns
    X = X[:, ~np.all(X == 0, axis=0)]

    # ols
    Xt = X.transpose()
    Xt_X = np.dot(Xt, X)
    Xt_X_inv = np.linalg.pinv(Xt_X)
    Xt_X_inv_Xt = np.dot(Xt_X_inv, Xt)
    beta_hat = np.dot(Xt_X_inv_Xt, y)

    return beta_hat

def recenter(X, y):
    X = X - np.mean(X, 0)
    y = y - np.mean(y)

    return X, y

def ridge(X, y, fLambda):
    X = np.array(X)
    y = np.array(y)
    
    # delete zero rows
    X = X[~np.all(X == 0, axis=1)]
    
    # delete zero columns
    X = X[:, ~np.all(X == 0, axis=0)]
    
    # ridge
    Xt = X.transpose()
    Xt_X = np.dot(Xt, X)
    lambda_I = fLambda * np.identity(X.shape[1])
    Xt_X_lambda_I_inv = np.linalg.inv(Xt_X + lambda_I)
    Xt_X_lambda_I_inv_Xt = np.dot(Xt_X_lambda_I_inv, Xt)
    beta_hat = np.dot(Xt_X_lambda_I_inv_Xt, y)

    return beta_hat

# new function to get the cols removed, got code from ols
def get_removed_col_indices(X):
    X = np.array(X)
    original_cols = np.arange(X.shape[1])
    non_zero_cols = ~np.all(X  == 0, axis=0)
    removed_cols = original_cols[~non_zero_cols]
    return removed_cols, original_cols

# new function to remove features
def remove_features(feat_list, removed_cols):
  return [feature for i, feature in enumerate(feat_list) if i not in removed_cols]

# prediction
def predict(X, beta):
  X = np.array(X)
  X = X[:, ~np.all(X==0, axis=0)]
  beta = np.array(beta)
  y_hat = np.dot(X, beta)

  return y_hat

# calculate mse
def mean_squared_error(y_hat, y):
  mse = np.mean((y.flatten() - y_hat) ** 2)

  return mse

# %% [markdown]
# # 1. OLS Regression

# %% [markdown]
# ## 1-1. load_data()

# %%
X_raw, y = load_data(file="data/iowa.csv")
y
# Out:
# ['4499.84',
#  '4598.18',
#  '4840.74',
#  '3828.55',
#  '4691.36',
#  '2410.09',
#  '3672.24',
#  '2836.75',
#  '2938.72',
#  '2105.74',
#  '1793.33',
#  '3507.85',
#  '486.98',
#  '544.34',
#  '831.8399999999999',
#  '102.0',
#  '294.0',
#  '1563.84',
#  '1202.16',
#  '1525.2',
#  '1256.16',
#  '495.12',
#  '984.6',
#  '450.48',
#  '877.8000000000002',
#  '9494.44',
#  '14529.21',
#  '19482.74',
#  '17362.5',
#  '13655.67',
#  '21574.42',
#  '14837.93',
#  '16636.43',
#  '19035.71',
#  '14874.43',
#  '17111.48',
#  '22558.8',
#  '9904.46',
#  '7945.599999999999',
#  '5346.0',
#  '7236.809999999999',
#  '6814.63',
#  '6366.48',
#  '10028.69',
#  '7121.56',
#  '8110.29',
#  '6354.69',
#  '7392.8',
#  '8375.86',
#  '1025.14',
#  '1092.56',
#  '2010.66',
#  '2292.18',
#  '2352.6',
#  '1737.84',
#  '2580.4700000000003',
#  '1977.49',
#  '3923.7',
#  '2645.84',
#  '1638.03',
#  '4271.68',
#  '335.16',
#  '341.52',
#  '419.15',
#  '440.2000000000001',
#  '408.18',
#  '427.25',
#  '416.2000000000001',
#  '355.28000000000003',
#  '349.33',
#  '410.04',
#  '558.59',
#  '693.22',
#  '369.77',
#  '617.04',
#  '733.85',
#  '355.1',
#  '377.72',
#  '738.57',
#  '380.08',
#  '384.08',
#  '790.82',
#  '417.74',
#  '414.4',
#  '489.6000000000001',
#  '392.1',
#  '456.13',
#  '467.28',
#  '340.14000000000004',
#  '833.23',
#  '1135.9',
#  '405.96',
#  '438.34',
#  '964.37',
#  '829.8',
#  '958.76',
#  '16740.78',
#  '14859.25',
#  '16536.92',
#  '17890.83',
#  '13858.57',
#  '17811.82',
#  '11843.4',
#  '11414.47',
#  '15329.41',
#  '14111.04',
#  '12935.95',
#  '16444.87',
#  '7213.82',
#  '3900.02',
#  '4275.04',
#  '5546.72',
#  '6429.860000000001',
#  '4707.4800000000005',
#  '6782.5',
#  '3623.12',
#  '4847.57',
#  '5008.94',
#  '5876.73',
#  '4657.59',
#  '2235.29',
#  '3531.9700000000003',
#  '4607.04',
#  '2149.65',
#  '2034.55',
#  '2102.26',
#  '2445.49',
#  '2530.48',
#  '2081.77',
#  '2458.27',
#  '3465.55',
#  '2595.78',
#  '20782.49',
#  '21806.56',
#  '24338.79',
#  '23861.59',
#  '30888.75',
#  '29641.12',
#  '22063.5',
#  '24286.55',
#  '22813.04',
#  '23703.36',
#  '27344.81',
#  '35474.66',
#  '2613.62',
#  '1914.48',
#  '1686.15',
#  '2085.35',
#  '1896.73',
#  '2894.78',
#  '2752.2200000000003',
#  '1487.41',
#  '1524.33',
#  '1779.28',
#  '1667.34',
#  '3076.5600000000004',
#  '3162.88',
#  '2089.9',
#  '2405.41',
#  '3112.42',
#  '2741.92',
#  '2255.88',
#  '2903.86',
#  '2237.24',
#  '3493.7',
#  '2348.78',
#  '2155.66',
#  '3005.62',
#  '5440.01',
#  '999.8',
#  '661.9',
#  '712.1800000000001',
#  '961.14',
#  '2036.25',
#  '422.58',
#  '8095.76',
#  '6273.97',
#  '1976.81',
#  '1759.28',
#  '340.5',
#  '1999.38',
#  '13609.99',
#  '4357.9400000000005',
#  '2488.5',
#  '45.30000000000001',
#  '1865.96',
#  '1363.73',
#  '2537.42',
#  '1166.82',
#  '1504.18',
#  '1003.26',
#  '1119.88',
#  '836.0400000000001',
#  '1037.62',
#  '1549.89',
#  '1867.66',
#  '1958.55',
#  '4631.2300000000005',
#  '11355.69',
#  '8988.77',
#  '6950.38',
#  '8525.52',
#  '2743.55',
#  '3559.1800000000003',
#  '16213.55',
#  '7798.37',
#  '17956.44',
#  '5469.7',
#  '6162.08',
#  '2300.68',
#  '6023.25',
#  '4103.43',
#  '8971.06',
#  '7282.67',
#  '2610.62',
#  '3624.06',
#  '9739.9',
#  '7254.68',
#  '12079.41',
#  '3382.42',
#  '3037.05',
#  '366.35',
#  '348.24',
#  '412.39',
#  '348.88',
#  '321.35',
#  '1236.26',
#  '1604.54',
#  '1247.04',
#  '7622.68',
#  '7264.1',
#  '6005.67',
#  '6288.67',
#  '6528.360000000001',
#  '6009.34',
#  '8136.1',
#  '5990.35',
#  '7361.2',
#  '8628.94',
#  '5796.72',
#  '7508.29',
#  '6734.610000000001',
#  '5081.56',
#  '5642.97',
#  '6962.68',
#  '6416.24',
#  '5787.81',
#  '7633.57',
#  '5228.95',
#  '7304.72',
#  '6258.07',
#  '5430.22',
#  '13150.62',
#  '8707.7',
#  '13705.34',
#  '4918.79',
#  '7132.01',
#  '8603.31',
#  '6406.77',
#  '8636.0',
#  '7040.97',
#  '10639.36',
#  '7766.79',
#  '6340.67',
#  '9983.34',
#  '10762.43',
#  '17878.8',
#  '7128.9400000000005',
#  '6617.97',
#  '6480.78',
#  '6293.39',
#  '8422.88',
#  '9031.27',
#  '7965.59',
#  '7215.39',
#  '9996.48',
#  '8808.91',
#  '6120.32',
#  '10014.22',
#  '9097.13',
#  '1325.04',
#  '1530.0',
#  '669.0',
#  '1040.52',
#  '2166.0',
#  '840.12',
#  '6053.280000000001',
#  '1323.12',
#  '10658.34',
#  '6879.54',
#  '9027.33',
#  '5975.150000000001',
#  '6127.54',
#  '19611.6',
#  '18718.7',
#  '6500.23',
#  '5413.24',
#  '15677.95',
#  '14353.31',
#  '8864.789999999999',
#  '442.13',
#  '690.7900000000001',
#  '697.29',
#  '710.17',
#  '682.1',
#  '759.76',
#  '347.36',
#  '926.73',
#  '774.15',
#  '1321.71',
#  '375.0',
#  '609.5',
#  '782.46',
#  '976.08',
#  '720.46',
#  '765.12',
#  '1165.94',
#  '1319.26',
#  '945.09',
#  '143232.54',
#  '170501.3',
#  '200063.13',
#  '191893.49',
#  '248257.6',
#  '185245.95',
#  '168419.95',
#  '180677.34',
#  '137569.02',
#  '176361.48',
#  '198199.52',
#  '192289.71',
#  '1244.64',
#  '944.87',
#  '1026.55',
#  '1607.54',
#  '1688.57',
#  '1319.48',
#  '1527.18',
#  '1808.03',
#  '1590.34',
#  '1777.91',
#  '1724.85',
#  '1752.47',
#  '9863.6',
#  '3192.41',
#  '4984.3',
#  '5672.63',
#  '7166.76',
#  '4954.81',
#  '7569.93',
#  '3356.58',
#  '4770.12',
#  '3388.15',
#  '4239.38',
#  '4059.58',
#  '4179.62',
#  '3393.84',
#  '3361.19',
#  '4282.71',
#  '3335.87',
#  '2810.48',
#  '3675.58',
#  '2902.13',
#  '2499.98',
#  '2638.7',
#  '2904.5',
#  '3966.79',
#  '4528.64',
#  '6483.9800000000005',
#  '7856.56',
#  '6043.360000000001',
#  '7224.370000000001',
#  '8749.12',
#  '4810.08',
#  '8188.82',
#  '5716.53',
#  '6914.46',
#  '9397.78',
#  '7250.97',
#  '2452.54',
#  '2022.0',
#  '2924.83',
#  '3142.17',
#  '3012.66',
#  '2716.28',
#  '2990.5',
#  '3524.98',
#  '1656.38',
#  '3610.97',
#  '3974.19',
#  '2322.37',
#  '874.4399999999999',
#  '3527.26',
#  '2065.01',
#  '1990.61',
#  '1848.95',
#  '1643.96',
#  '2187.41',
#  '2927.44',
#  '2551.49',
#  '3839.47',
#  '1781.88',
#  '1676.77',
#  '1057.71',
#  '1332.22',
#  '1195.85',
#  '1277.26',
#  '1870.38',
#  '1127.55',
#  '1050.24',
#  '1137.0',
#  '1217.88',
#  '1360.64',
#  '1151.29',
#  '1415.42',
#  '3790.88',
#  '4064.28',
#  '5877.8',
#  '5223.49',
#  '4122.25',
#  '4869.75',
#  '6101.67',
#  '5542.36',
#  '5240.63',
#  '4316.14',
#  '5931.79',
#  '3975.26',
#  '3594.65',
#  '3844.62',
#  '5749.150000000001',
#  '3864.97',
#  '5376.73',
#  '7690.059999999999',
#  '4219.45',
#  '5500.849999999999',
#  '4501.39',
#  '10462.7',
#  '5225.79',
#  '4277.17',
#  '3522.9700000000003',
#  '2779.05',
#  '2392.07',
#  '3511.91',
#  '2986.74',
#  '2983.6',
#  '3002.49',
#  '3427.81',
#  '2711.79',
#  '2855.17',
#  '3147.39',
#  '3303.8',
#  '393.08',
#  '957.5',
#  '372.99',
#  '322.40000000000003',
#  '1190.55',
#  '819.62',
#  '718.51',
#  '698.72',
#  '718.3',
#  '374.0100000000001',
#  '422.92',
#  '10292.88',
#  '10726.08',
#  '9436.47',
#  '9788.37',
#  '12263.79',
#  '10907.08',
#  '11369.39',
#  '8924.33',
#  '7613.099999999999',
#  '9668.12',
#  '10015.99',
#  '9848.02',
#  '6371.27',
#  '8926.050000000001',
#  '10015.59',
#  '8105.400000000001',
#  '6687.33',
#  '6227.41',
#  '7366.88',
#  '10754.92',
#  '7111.42',
#  '11722.96',
#  '3405.53',
#  '7958.35',
#  '1801.44',
#  '1676.52',
#  '1797.15',
#  '1946.97',
#  '1750.17',
#  '3196.79',
#  '2561.39',
#  '3448.78',
#  '2629.2',
#  '2456.7',
#  '1621.42',
#  '1316.25',
#  '1443.2600000000002',
#  '1883.82',
#  '2571.11',
#  '910.38',
#  '347.58',
#  '951.34',
#  '353.94',
#  '1943.2',
#  '1512.1',
#  '1982.9',
#  '1209.42',
#  '780.09',
#  '442.85',
#  '392.62',
#  '395.65',
#  '355.86',
#  '500.81',
#  '1037.42',
#  '456.06',
#  '508.05',
#  '793.23',
#  '488.82',
#  '805.65',
#  '9088.32',
#  '7034.54',
#  '8993.58',
#  '10593.01',
#  '9352.26',
#  '9061.68',
#  '8575.84',
#  '8076.89',
#  '11819.81',
#  '10307.43',
#  '12925.01',
#  '10591.85',
#  '17699.51',
#  '16709.39',
#  '18159.32',
#  '23532.35',
#  '17073.22',
#  '18346.12',
#  '21553.69',
#  '16556.62',
#  '17122.82',
#  '22667.44',
#  '20521.35',
#  '26107.2',
#  '21856.1',
#  '33086.95',
#  '21513.61',
#  '29335.61',
#  '41769.24',
#  '21761.42',
#  '26931.09',
#  '19345.14',
#  '22247.11',
#  '26463.7',
#  '23841.79',
#  '25767.72',
#  '15274.45',
#  '15244.07',
#  '18087.91',
#  '12556.17',
#  '30443.71',
#  '15807.65',
#  '16196.39',
#  '18876.87',
#  '12175.6',
#  '13967.69',
#  '20271.05',
#  '21908.31',
#  '13835.6',
#  '17502.97',
#  '11848.14',
#  '15743.15',
#  '17890.01',
#  '18222.26',
#  '17397.14',
#  '12621.29',
#  '14313.49',
#  '9134.38',
#  '12330.68',
#  '30273.86',
#  '1596.02',
#  '3456.14',
#  '4717.5',
#  '4241.77',
#  '3492.34',
#  '3109.48',
#  '6897.38',
#  '4486.54',
#  '5533.32',
#  '4411.99',
#  '3995.35',
#  '3361.44',
#  '4712.6',
#  '6513.72',
#  '6728.11',
#  '7199.46',
#  '9560.47',
#  '12657.54',
#  '9318.53',
#  '9381.4',
#  '8864.380000000001',
#  '10294.86',
#  '9629.8',
#  '7371.71',
#  '10504.84',
#  '141854.76',
#  '125635.85',
#  '139162.31',
#  '136198.07',
#  '168682.07',
#  '135141.7',
#  '163011.56',
#  '133893.03',
#  '130504.46',
#  '171940.83',
#  '132380.33',
#  '141678.4',
#  '3210.24',
#  '6260.490000000001',
#  '5053.14',
#  '4715.02',
#  '6279.4800000000005',
#  '4516.24',
#  '5125.41',
#  '6743.63',
#  '4743.400000000001',
#  '6233.88',
#  '5421.93',
#  '4590.45',
#  '2847.35',
#  '4016.2',
#  '4713.14',
#  '3015.62',
#  '5306.4800000000005',
#  '2806.66',
#  '2559.56',
#  '4278.09',
#  '3241.02',
#  '4866.96',
#  '2881.86',
#  '6869.31',
#  '6397.4',
#  '464.07',
#  '5708.93',
#  '13994.1',
#  '6881.82',
#  '9001.32',
#  '5889.45',
#  '9267.27',
#  '5875.18',
#  '8142.13',
#  '9265.0',
#  '8230.6',
#  '4927.77',
#  '4304.87',
#  '6375.03',
#  '5331.36',
#  '4668.150000000001',
#  '6152.43',
#  '5805.56',
#  '5426.360000000001',
#  '4817.59',
#  '4453.94',
#  '4043.42',
#  '5791.91',
#  '1012.87',
#  '477.66',
#  '671.13',
#  '728.22',
#  '1315.42',
#  '675.81',
#  '673.24',
#  '666.99',
#  '776.5',
#  '1004.64',
#  '667.78',
#  '711.73',
#  '667.65',
#  '236.46',
#  '337.92',
#  '1052.87',
#  '1349.59',
#  '924.47',
#  '348.23',
#  '668.61',
#  '1003.41',
#  '1232.82',
#  '669.64',
#  '690.0',
#  '1010.8',
#  '541.33',
#  '669.78',
#  '707.23',
#  '1253.34',
#  '801.29',
#  '667.73',
#  '669.54',
#  '1005.05',
#  '1210.87',
#  '765.11',
#  '391.52',
#  '755.04',
#  '1230.38',
#  '1273.46',
#  '1258.03',
#  '1689.85',
#  '1113.0',
#  '1046.48',
#  '1421.21',
#  '999.07',
#  '1158.72',
#  '1001.27',
#  '1290.06',
#  '854.4200000000001',
#  '1245.29',
#  '1249.67',
#  '905.22',
#  '1617.3',
#  '1180.56',
#  '755.01',
#  '696.52',
#  '916.14',
#  '1967.65',
#  '881.29',
#  '1013.0',
#  '2028.75',
#  '745.47',
#  '334.1',
#  '592.72',
#  '677.64',
#  '335.45',
#  '1160.77',
#  '338.95',
#  '467.41',
#  '601.76',
#  '366.24',
#  '3044.4500000000003',
#  '2716.33',
#  '2662.83',
#  '3756.4',
#  '3550.08',
#  '2878.87',
#  '3511.24',
#  '2426.83',
#  '2842.01',
#  '3234.41',
#  '2867.0',
#  '2972.52',
#  '2050.04',
#  '1777.53',
#  '1747.14',
#  '2623.41',
#  '2316.75',
#  '2120.69',
#  '1995.35',
#  '1495.54',
#  '2408.07',
#  '1592.82',
#  '1583.79',
#  '1722.48',
#  '4884.31',
#  '5731.04',
#  '4182.42',
#  '3847.9',
#  '6274.79',
#  '4134.56',
#  '6342.12',
#  '4855.42',
#  '4012.2',
#  '6270.9800000000005',
#  '5549.7',
#  '8650.68',
#  '8877.86',
#  '9486.47',
#  '5737.96',
#  '13379.11',
#  '10059.65',
#  '9280.6',
#  '9653.19',
#  '12289.06',
#  '8972.68',
#  '12603.53',
#  '8234.14',
#  '9920.18',
#  '755.39',
#  '737.23',
#  '922.44',
#  '819.24',
#  '650.1600000000001',
#  '884.61',
#  '2582.11',
#  '2665.89',
#  '3241.66',
#  '3207.28',
#  '3578.34',
#  '3780.67',
#  '3036.63',
#  '3407.65',
#  '3877.31',
#  '610.86',
#  '704.55',
#  '1312.13',
#  '2693.12',
#  '1813.15',
#  '3192.46',
#  '2203.15',
#  '1314.12',
#  '2340.6800000000003',
#  '1994.33',
#  '1949.95',
#  '2845.44',
#  '2070.29',
#  '4083.8',
#  '1653.05',
#  '3938.8',
#  '2932.2',
#  '4446.4400000000005',
#  '2885.3',
#  '3581.06',
#  '3372.79',
#  '3394.33',
#  '2589.32',
#  '3726.67',
#  '3582.9',
#  '4488.22',
#  '3763.91',
#  '3166.14',
#  '2936.64',
#  '3364.01',
#  '2383.69',
#  '2714.98',
#  '2200.62',
#  '2141.46',
#  '1145.5',
#  '997.82',
#  '1791.55',
#  '2685.18',
#  '2661.6',
#  '525.4200000000001',
#  '474.06',
#  '896.84',
#  '1168.58',
#  '1155.0600000000002',
#  '961.06',
#  '3086.0',
#  '2013.48',
#  '1610.33',
#  '2097.3',
#  '1642.26',
#  '2083.85',
#  '1350.54',
#  '1425.47',
#  '781.9799999999999',
#  '2190.08',
#  '1696.16',
#  '1853.66',
#  '17388.94',
#  '10769.59',
#  '11500.39',
#  '16012.32',
#  '13228.37',
#  '15428.0',
#  '11350.69',
#  '10698.32',
#  '11192.86',
#  '14312.44',
#  '13755.8',
#  '12452.4',
#  '1439.1',
#  '1066.32',
#  '1041.6',
#  '1055.88',
#  '1122.24',
#  '1477.04',
#  '1526.94',
#  '1140.54',
#  '1118.76',
#  '1131.6',
#  '1566.18',
#  '683.5200000000001',
#  '795.45',
#  '343.71',
#  '359.1',
#  '732.24',
#  '764.94',
#  '338.34000000000003',
#  '1071.57',
#  '397.59',
#  '711.36',
#  '351.0',
#  '712.62',
#  '383.16',
#  '10086.57',
#  '3947.81',
#  '1721.75',
#  '1729.71',
#  '2601.2000000000003',
#  '1731.57',
#  '3745.8',
#  '714.69',
#  '693.54',
#  '817.78',
#  '1600.98',
#  '1028.21',
#  '733.74',
#  '755.78',
#  '830.58',
#  '538.57',
#  '1276.16',
#  '1258.08',
#  '2536.91',
#  '1485.79',
#  '2815.3',
#  '1581.17',
#  '2000.7',
#  '2024.64',
#  '815.39',
#  '1154.17',
#  '1511.87',
#  '2091.41',
#  '2091.0',
#  '1262.15',
#  '4016.6',
#  '10506.76',
#  '3525.03',
#  '6369.7300000000005',
#  '5504.54',
#  '5711.75',
#  '7852.26',
#  '6269.74',
#  '7231.32',
#  '7941.14',
#  '7453.99',
#  '5210.26',
#  '1370.76',
#  '1118.3',
#  '1445.34',
#  '1629.04',
#  '2545.34',
#  '3333.05',
#  '2132.57',
#  '2244.96',
#  '1217.64',
#  '3034.31',
#  '1976.49',
#  '2059.18',
#  '1546.11',
#  '625.23',
#  '3052.23',
#  '2279.3100000000004',
#  '1630.3',
#  '2915.61',
#  '1814.47',
#  '2040.71',
#  '3728.22',
#  '1834.62',
#  '1811.94',
#  '3324.77',
#  '954.76',
#  '1197.81',
#  '961.97',
#  '846.46',
#  '1317.5',
#  '1496.62',
#  '1116.2',
#  '628.8299999999999',
#  '1930.29',
#  '549.46',
#  '990.16',
#  '913.59',
#  '725.22',
#  '959.92',
#  '438.48',
#  '673.99',
#  '1333.0',
#  '749.6',
#  '506.84',
#  '874.7600000000001',
#  '889.32',
#  '722.6400000000001',
#  '858.44',
#  '1019.8',
#  '342.92',
#  '6844.35',
#  '5659.22',
#  '4406.56',
#  '6589.82',
#  '4338.54',
#  '6104.32',
#  '4572.75',
#  '3797.83',
#  '3594.88',
#  '3706.4',
#  '3452.92',
#  '5702.23',
#  '1602.24',
#  '192.12',
#  '681.0600000000001',
#  '362.16',
#  ...]

# %%
X_raw[0]
# Out:
# {'cat_convenience_store': '0',
#  'cat_distillery_brewery': '0',
#  'cat_gas_station': '0',
#  'cat_general_store': '0',
#  'cat_grocery': '0',
#  'cat_liquor_store_bar': '1',
#  'cat_other': '0',
#  'cat_pharmacy': '0',
#  'cat_unknown': '0',
#  'female_18_24': '351',
#  'female_25_34': '445',
#  'female_35_44': '464',
#  'female_45_64': '1051',
#  'female_65_over': '1093',
#  'male_18_24': '406',
#  'male_25_34': '491',
#  'male_35_44': '571',
#  'male_45_64': '1071',
#  'male_65_over': '872',
#  'annual_income': '65080',
#  'excessive_drinking': '26',
#  'gassale_x_gasstore': '0',
#  'l_10th_mountain_american_single_malt': '0',
#  'l_10th_mountain_bourbon': '0',
#  'l_10th_mountain_brandy': '0',
#  'l_10th_mountain_cordial': '0',
#  'l_10th_mountain_rye': '0',
#  'l_10th_mountain_vodka': '0',
#  'l_135_east_hyogo_japanese_gin': '0',
#  'l_15_stars_private_stock_8_and_15yr': '0',
#  'l_173_craft_distillery_barrel_kane': '0',
#  'l_173_craft_distillery_bourbon_whiskey': '0',
#  'l_173_craft_distillery_broken_beaker_silver_rum': '0',
#  'l_173_craft_distillery_premium_gin': '0',
#  'l_173_craft_distillery_premium_vodka': '0',
#  'l_173_craft_distillery_single_barrel_bourbon': '0',
#  'l_173_craft_distillery_spiced_rum': '0',
#  'l_173_craft_distillery_volumetric_vodka': '0',
#  'l_1792_12yr_old_bourbon': '0',
#  'l_1792_bottled_in_bond_bourbon': '0',
#  'l_1792_bottled_in_bond_bourbon_barrel': '0',
#  'l_1792_chocolate_bourbon_ball_cream': '0',
#  'l_1792_full_proof': '0',
#  'l_1792_full_proof_buy_the_barrel': '0',
#  'l_1792_full_proof_kentucky_sazerac_barrel_select_straight_bour': '0',
#  'l_1792_single_barrel_bourbon': '0',
#  'l_1792_single_barrel_kentucky_straight_bourbon_sazerac_barrel': '0',
#  'l_1792_small_batch': '0',
#  'l_1792_small_batch_bourbon': '0',
#  'l_1792_sweet_wheat_bourbon': '0',
#  'l_1800_anejo': '0',
#  'l_1800_coconut': '0',
#  'l_1800_cristalino': '0',
#  'l_1800_cucumber_jalapeno': '0',
#  'l_1800_passion_fruit_ultimate_margarita': '0',
#  'l_1800_reposado': '0',
#  'l_1800_reposado_with_taco_tray_vap': '0',
#  'l_1800_silver': '0',
#  'l_1800_silver_mini': '0',
#  'l_1800_tequila_blanco': '0',
#  'l_1800_tequila_blanco_w_dipping_bowl': '0',
#  'l_1800_ultimate_black_cherry_margarita_pet': '0',
#  'l_1800_ultimate_blood_orange_margarita': '0',
#  'l_1800_ultimate_blood_orange_margarita_pet': '0',
#  'l_1800_ultimate_mango_margarita': '0',
#  'l_1800_ultimate_mango_margarita_pet': '0',
#  'l_1800_ultimate_margarita': '0',
#  'l_1800_ultimate_margarita_pet': '0',
#  'l_1800_ultimate_peach_margarita': '0',
#  'l_1800_ultimate_peach_margarita_pet': '0',
#  'l_1800_ultimate_pineapple_margarita': '0',
#  'l_1800_ultimate_pineapple_margarita_pet': '0',
#  'l_1800_ultimate_raspberry_margarita_pet': '0',
#  'l_1800_ultimate_strawberry_margarita': '0',
#  'l_1800_ultimate_strawberry_margarita_pet': '0',
#  'l_1800_ultimate_watermelon_margarita': '0',
#  'l_1800_ultimate_watermelon_margarita_pet': '0',
#  'l_1800_ultimate_wild_berry_margarita': '0',
#  'l_1921_tequila_anejo': '0',
#  'l_1921_tequila_blanco': '0',
#  'l_1921_tequila_cream': '0',
#  'l_1921_tequila_reposado': '0',
#  'l_2_gingers': '0',
#  'l_21seeds_cucumber_jalapeno_tequila': '0',
#  'l_21seeds_grapefruit_hibiscus': '0',
#  'l_21seeds_valencia_orange_tequila': '0',
#  'l_2xo_french_oak': '0',
#  'l_2xo_gem_of_kentucky_2024_release': '0',
#  'l_2xo_kiawah_blend': '0',
#  'l_2xo_oak_series': '0',
#  'l_2xo_sneaker_head': '0',
#  'l_2xo_tribute': '0',
#  'l_360_concord_grape': '0',
#  'l_360_double_chocolate': '0',
#  'l_360_georgia_peach': '0',
#  'l_360_huckleberry': '0',
#  'l_360_madagascar_vanilla': '0',
#  'l_360_mandarin_orange': '0',
#  'l_360_mango': '0',
#  'l_360_red_delicious_apple': '0',
#  'l_360_red_raspberry': '0',
#  'l_360_vodka': '0',
#  'l_360_watermelon': '0',
#  'l_400_conejos_cuishe': '0',
#  'l_400_conejos_mezcal': '0',
#  'l_44_north_huckleberry': '0',
#  'l_44_north_potato_vodka': '0',
#  'l_44_north_sunnyslope_nectarine_vodka': '0',
#  'l_7_drops_apple': '0',
#  'l_7_drops_lychee': '0',
#  'l_7_drops_original': '0',
#  'l_7_drops_passion_fruit': '0',
#  'l_7_drops_watermelon': '0',
#  'l_7_drops_yogurt': '0',
#  'l_818_anejo_tequila': '0',
#  'l_818_blanco_tequila': '0',
#  'l_818_reposado_tequila': '0',
#  'l_818_tequila_blanco': '0',
#  'l_818_tequila_reposado': '0',
#  'l_99_apples': '0',
#  'l_99_apples_mini_display': '0',
#  'l_99_bananas': '0',
#  'l_99_bananas_mini': '0',
#  'l_99_blackberries': '0',
#  'l_99_blackberries_mini': '0',
#  'l_99_blue_raspberries_mini': '0',
#  'l_99_brand_adult_variety_trick_treat_bag_mini': '0',
#  'l_99_brand_candy_canes_mini': '0',
#  'l_99_brand_cherry_limeade_pet_mini': '0',
#  'l_99_brand_flavored_lemonades_mini': '0',
#  'l_99_brand_fruit_punch_pet_mini': '0',
#  'l_99_brand_guava_mini': '0',
#  'l_99_brand_mystery_flavor_pet_mini': '0',
#  'l_99_brand_peanut_butter_whiskey': '0',
#  'l_99_brand_variety_party_yard_pack_mini': '0',
#  'l_99_butterscotch': '0',
#  'l_99_butterscotch_mini': '0',
#  'l_99_cherries': '0',
#  'l_99_cherries_mini': '0',
#  'l_99_chocolate_mini': '0',
#  'l_99_cinnamon': '0',
#  'l_99_cinnamon_mini': '0',
#  'l_99_fruits_mini': '1',
#  'l_99_grapes': '0',
#  'l_99_grapes_pet_mini': '0',
#  'l_99_lemon_lime': '0',
#  'l_99_lemon_lime_mini': '0',
#  'l_99_long_island_iced_tea_mini': '0',
#  'l_99_mangoes': '0',
#  'l_99_mangoes_mini': '0',
#  'l_99_oranges': '0',
#  'l_99_oranges_mini': '0',
#  'l_99_party_bucket_minis': '0',
#  'l_99_peaches': '0',
#  'l_99_peaches_pet_mini': '0',
#  'l_99_peanut_butter_whiskey_mini': '0',
#  'l_99_peppermint': '0',
#  'l_99_peppermint_mini': '0',
#  'l_99_pickle_mini': '0',
#  'l_99_pineapple': '0',
#  'l_99_pineapple_mini': '0',
#  'l_99_pink_lemonade_mini': '0',
#  'l_99_punches_variety_mini': '0',
#  'l_99_rainbow_pack_mini': '0',
#  'l_99_root_beer': '0',
#  'l_99_root_beer_mini': '0',
#  'l_99_salted_caramel_mini': '0',
#  'l_99_sour_apple_mini': '0',
#  'l_99_sour_berry_mini': '0',
#  'l_99_sour_cherry_mini': '0',
#  'l_99_strawberries_mini': '0',
#  'l_99_toasted_flavorites_mini': '0',
#  'l_99_watermelon_pet_mini': '0',
#  'l_99_watermelon_schnapps': '0',
#  'l_99_whipped': '0',
#  'l_99_whipped_mini': '0',
#  'l_99_whiskey_mini': '0',
#  'l_99_xxpresso_mini': '0',
#  'l_a_overholt_rye_whiskey': '0',
#  'l_aalborg_jubilaeums_aquavit': '0',
#  'l_aberfeldy_12yr': '0',
#  'l_aberlour_12yr': '0',
#  'l_aberlour_16yr': '0',
#  'l_aberlour_18yr': '0',
#  'l_aberlour_a_bunadh': '0',
#  'l_aberlour_abunadh_alba': '0',
#  'l_absente': '0',
#  'l_absinthia_absinthe_barrel_aged': '0',
#  'l_absinthia_absinthe_blanche': '0',
#  'l_absinthia_absinthe_verte': '0',
#  'l_absolut_apeach': '0',
#  'l_absolut_blue_w_cranberry_juice': '0',
#  'l_absolut_citron': '0',
#  'l_absolut_elyx': '0',
#  'l_absolut_grapefruit': '0',
#  'l_absolut_lime': '0',
#  'l_absolut_lime_mini': '0',
#  'l_absolut_mandrin': '0',
#  'l_absolut_mandrin_mini': '0',
#  'l_absolut_mango': '0',
#  'l_absolut_mini_bar': '0',
#  'l_absolut_mojito_ready_to_serve': '0',
#  'l_absolut_pears': '0',
#  'l_absolut_peppar': '0',
#  'l_absolut_raspberri': '0',
#  'l_absolut_raspberry_lemonade_ready_to_serve': '0',
#  'l_absolut_swedish_vodka_80prf': '0',
#  'l_absolut_swedish_vodka_80prf_mini': '0',
#  'l_absolut_vanilia': '0',
#  'l_absolut_w_fever_tree_ginger_beer': '0',
#  'l_absolut_w_kahlua_50ml_and_espresso_martini_mix': '0',
#  'l_absolut_watermelon': '0',
#  'l_absolut_wild_berry': '0',
#  'l_adictivo_anejo': '0',
#  'l_adictivo_anejo_black': '0',
#  'l_adictivo_anejo_blue_label_ceramic': '0',
#  'l_adictivo_anejo_tequila': '0',
#  'l_adictivo_extra_anejo': '0',
#  'l_adictivo_extra_anejo_14yr_double_black': '0',
#  'l_adictivo_extra_anejo_14yr_extra_rare': '0',
#  'l_adictivo_extra_anejo_cristalino': '0',
#  'l_adictivo_plata': '0',
#  'l_adictivo_reposado': '0',
#  'l_adictivo_reposado_cristalino': '0',
#  'l_adictivo_whiskey_small_batch': '0',
#  'l_admiral_nelson_cherry_spiced': '0',
#  'l_admiral_nelson_coconut': '0',
#  'l_admiral_nelson_spiced': '0',
#  'l_admiral_nelson_spiced_101': '0',
#  'l_admiral_nelson_spiced_mini': '0',
#  'l_admiral_nelson_spiced_pet': '0',
#  'l_agavero_orange_tequila_liqueur': '0',
#  'l_akashi_whisky': '0',
#  'l_alander_nordic_spiced_rum': '0',
#  'l_alto_del_carmen_pisco_reservado': '0',
#  'l_alvisa_10yr_brandy': '0',
#  'l_alvisa_honey': '0',
#  'l_alvisa_xo_brandy': '0',
#  'l_amador_double_barrel_low_rye_cabernet_finish': '0',
#  'l_amador_double_barrel_wheat_bourbon_chardonnay': '0',
#  'l_amador_kentucky_rye_port_finish': '0',
#  'l_aman_tequila_reposado': '0',
#  'l_amaretto_e_dolce': '0',
#  'l_amaro_braulio': '0',
#  'l_amaro_montenegro': '0',
#  'l_amaro_montenegro_w_glass': '0',
#  'l_amarula_cream_liqueur': '0',
#  'l_amarula_cream_liqueur_w_2_glasses': '0',
#  'l_american_born_apple_pie_whiskey': '0',
#  'l_american_born_apple_pie_whiskey_mini': '0',
#  'l_american_born_bourbon_whiskey': '0',
#  'l_american_born_moonshine_apple_pie': '0',
#  'l_american_harvest_organic_red_vodka': '0',
#  'l_american_premium_vodka': '0',
#  'l_ancho_reyes': '0',
#  'l_ancho_reyes_barrica': '0',
#  'l_ancient_age_10_star_bourbon': '1',
#  'l_ancient_age_bourbon': '6',
#  'l_ancnoc_12yr': '0',
#  'l_ancnoc_18yr_single_malt_scotch': '0',
#  'l_angels_envy_bourbon': '0',
#  'l_angels_envy_bourbon_port_finished': '0',
#  'l_angels_envy_buy_the_barrel': '0',
#  'l_angels_envy_rye': '0',
#  'l_angostura_5yr_gold_rum': '0',
#  'l_angostura_7yr_dark_caribbean_rum': '0',
#  'l_angostura_di_amaro_liqueur': '0',
#  'l_angostura_rum_1919': '0',
#  'l_ansac_vs_cognac': '0',
#  'l_ao_suntory_world_whisky': '0',
#  'l_aperol': '0',
#  'l_aperol_summer_gift_pack_with_spritz_glass': '0',
#  'l_aperol_use_code_64105': '0',
#  'l_aperol_w_aperol_spritz_glass': '0',
#  'l_appleton_12yr_estate_rare_casks': '0',
#  'l_appleton_8yr_reserve': '0',
#  'l_appleton_estate_15yr_black_river_casks': '0',
#  'l_appleton_estate_signature_blend': '0',
#  'l_aqua_perfecta_basil_eau_de_vie': '0',
#  'l_arak_brun_5_year_special_reserve': '0',
#  'l_arak_ksarak': '0',
#  'l_arandas_white_tequila': '0',
#  'l_ardbeg_10yr_islay': '0',
#  'l_ardbeg_an_oa': '0',
#  'l_ardbeg_anamorphic': '0',
#  'l_ardbeg_anthology_14yo_gb_2024_edition': '0',
#  'l_ardbeg_corryvreckan': '0',
#  'l_ardbeg_spectacular_ardbeg_day': '0',
#  'l_ardbeg_uigeadail': '0',
#  'l_ardbeg_wee_beastie': '0',
#  'l_ardnamurchan_highland_single_malt_whisky': '0',
#  'l_arette_artesanal_suave_anejo_tequila': '0',
#  'l_arette_artesanal_suave_reposado': '0',
#  'l_arette_suave_blanco_tequila': '0',
#  'l_arette_suave_fuerte_blanco_tequila': '0',
#  'l_arran_10yr_single_malt_scotch': '0',
#  'l_arran_bothy_quarter_cask': '0',
#  'l_arrogant_bastard_whiskey': '0',
#  'l_arrow_anisette': '0',
#  'l_arrow_apricot_brandy': '0',
#  'l_arrow_blackberry_brandy': '0',
#  'l_arrow_creme_de_almond': '3',
#  'l_arrow_creme_de_cacao_brown': '0',
#  'l_arrow_creme_de_cacao_white': '0',
#  'l_arrow_creme_de_cassis': '0',
#  'l_arrow_creme_de_menthe_green': '0',
#  'l_arrow_creme_de_menthe_white': '0',
#  'l_arrow_mcdales_butterscotch_schnapps': '0',
#  'l_arrow_peach_schnapps': '0',
#  'l_arrow_peppermint_schnapps': '0',
#  'l_arrow_peppermint_schnapps_mini': '0',
#  'l_arrow_raspberry_schnapps': '0',
#  'l_arrow_spearmint_schnapps': '0',
#  'l_arrow_wild_cherry_brandy': '0',
#  'l_artenom_1123_blanco_historico_tequila': '0',
#  'l_artenom_1146_anejo_tequila': '0',
#  'l_artenom_1414_reposado_tequila': '0',
#  'l_artenom_seleccion_de_1579_blanco': '0',
#  'l_artists_blend_blend_scotch': '0',
#  'l_asbach_15yr_brandy': '0',
#  'l_asombroso_gran_reserva_extra_anejo': '0',
#  'l_asombroso_la_rosa_reposado': '0',
#  'l_asombroso_silver_tequila': '0',
#  'l_aspen_vodka': '0',
#  'l_astral_anejo_tequila': '0',
#  'l_astral_margarita_cocktail': '0',
#  'l_astral_reposado': '0',
#  'l_astral_tequila': '0',
#  'l_atomic_drop_au79': '0',
#  'l_atomic_drop_co27': '0',
#  'l_atomic_drop_cu29': '0',
#  'l_atomic_drop_hg80': '0',
#  'l_auchentoshan_12yr': '0',
#  'l_auchentoshan_american_oak': '0',
#  'l_auchentoshan_three_wood': '0',
#  'l_autentica_de_mi_pueblo_anejo_agave_spirit': '0',
#  'l_autentica_de_mi_pueblo_plata_agave_spirit': '0',
#  'l_autentica_de_mi_pueblo_reposado_agave_spirit': '0',
#  'l_averna_amaro': '0',
#  'l_aveze_gentiane_liqueur': '0',
#  'l_aviation_american_gin': '0',
#  'l_avion_cristalino': '0',
#  'l_avion_reposado': '0',
#  'l_avion_reserva_44': '0',
#  'l_avion_silver': '0',
#  'l_axe_man_whiskey': '0',
#  'l_azteca_azul_plata': '0',
#  'l_azteca_azul_plata_tequila': '0',
#  'l_azteca_azul_reposado_tequila': '0',
#  'l_b_b_dom': '0',
#  'l_bacardi_8': '0',
#  'l_bacardi_anejo_cuatro': '0',
#  'l_bacardi_bahama_mama_rts': '0',
#  'l_bacardi_black': '0',
#  'l_bacardi_coconut_rum': '0',
#  'l_bacardi_coquito': '0',
#  'l_bacardi_dragon_berry': '0',
#  'l_bacardi_gold': '0',
#  'l_bacardi_gold_mini': '0',
#  'l_bacardi_gold_pet': '0',
#  'l_bacardi_hurricane_rts': '0',
#  'l_bacardi_lime': '0',
#  'l_bacardi_limon': '0',
#  'l_bacardi_mango_chile': '0',
#  'l_bacardi_mojito_rts': '0',
#  'l_bacardi_ocho_gift_tube': '0',
#  'l_bacardi_pineapple_fusion': '0',
#  'l_bacardi_pineapple_mai_tai': '0',
#  'l_bacardi_raspberry': '0',
#  'l_bacardi_reserva_ocho_sevillian_orange_cask': '0',
#  'l_bacardi_rum_punch_rts': '0',
#  'l_bacardi_spiced_rum': '0',
#  'l_bacardi_superior': '0',
#  'l_bacardi_superior_mini': '0',
#  'l_bacardi_superior_pet': '6',
#  'l_bacardi_zombie_rts': '0',
#  'l_badel_stara_sljivovica_premium_selection': '0',
#  'l_badel_williams_pear_brandy': '0',
#  'l_bagger_vodka': '0',
#  'l_baileys_almande': '0',
#  'l_baileys_chocolate': '0',
#  'l_baileys_cinnamon_churros_liqueur': '0',
#  'l_baileys_deliciously_light': '0',
#  'l_baileys_expresso': '0',
#  'l_baileys_original_irish_cream': '0',
#  'l_baileys_original_irish_cream_100ml': '0',
#  'l_baileys_original_irish_cream_mini': '0',
#  'l_baileys_original_irish_cream_w_glass_mug': '0',
#  'l_baileys_salted_caramel': '0',
#  'l_baileys_smores': '0',
#  'l_baileys_strawberries_cream': '0',
#  'l_baileys_vanilla_cinnamon': '0',
#  'l_baileys_vanilla_mint_shake': '0',
#  'l_bakers_7yr': '0',
#  'l_bakers_high_rye_bourbon': '0',
#  'l_bakon': '0',
#  'l_balcones_1_texas_single_malt': '0',
#  'l_balcones_brimstone': '0',
#  'l_balcones_lineage_single_malt': '0',
#  'l_ballantines_finest_blended_scotch_whisky': '0',
#  'l_ballotin_chocolate_cherry_cream_whiskey': '0',
#  'l_ballotin_chocolate_mocha_cream_whiskey': '0',
#  'l_ballotin_chocolate_peanut_butter_cream': '0',
#  'l_ballotin_chocolate_toffee_whiskey': '0',
#  'l_ballotin_chocolate_whiskey_bourbon_ball': '2',
#  'l_ballotin_chocolate_whiskey_caramel_turtle': '0',
#  'l_ballotin_chocolate_whiskey_caramel_turtle_mini': '0',
#  'l_ballotin_chocolate_whiskey_chocolate_mint': '0',
#  'l_ballotin_chocolate_whiskey_mini': '0',
#  'l_ballotin_peanut_butter_chocolate_whiskey': '0',
#  'l_ballotin_peanut_butter_chocolate_whiskey_mini': '0',
#  'l_baluarte_anejo_tequila': '0',
#  'l_baluarte_blanco_tequila': '0',
#  'l_baluarte_reposado_tequila': '0',
#  'l_balvenie_12yr_american_oak': '0',
#  'l_balvenie_12yr_doublewood': '0',
#  'l_balvenie_14yr_caribbean_cask': '0',
#  'l_balvenie_21yr_portwood': '0',
#  'l_bandoeng_22_pandan': '0',
#  'l_banhez_mezcal_ensamble': '0',
#  'l_banhez_mezcal_joven': '0',
#  'l_bankers_club_bourbon_reserve_5yr': '0',
#  'l_barbancourt_3_rhum_4yr': '0',
#  'l_barbancourt_5_rhum_8yr': '0',
#  'l_barbancourt_estate_reserve_rhum_15yr': '0',
#  'l_barcelo_organic_rum': '0',
#  'l_barenjager_honey_liq_w_2_boot_shaped_shot_glasses': '0',
#  'l_barenjager_honey_liqueur': '0',
#  'l_barr_hill_gin': '0',
#  'l_barr_hill_reserve_tom_cat_gin': '0',
#  'l_barrel_bourbon_vantage': '0',
#  'l_barrel_single_barrel_bourbon': '0',
#  'l_barrell_armida_bourbon': '0',
#  'l_barrell_bourbon_batch_035': '0',
#  'l_barrell_bourbon_batch_036': '0',
#  'l_barrell_bourbon_cask_finish_series_mizunara': '0',
#  'l_barrell_bourbon_dovetail_whiskey': '0',
#  'l_barrell_bourbon_dovetail_whiskey_use_code_86576': '0',
#  'l_barrell_bourbon_private_release': '0',
#  'l_barrell_foundation_bourbon': '0',
#  'l_barrell_seagrass': '0',
#  'l_barrell_whiskey_infinite_barrel_project': '0',
#  'l_barsol_acholado_pisco': '0',
#  'l_barsol_primero_quebranta_pisco': '0',
#  'l_bartenders_hot_sex': '0',
#  'l_bartenders_trading_company_awesome_orange': '0',
#  'l_bartenders_trading_company_pina_colada': '0',
#  'l_barton_gin': '0',
#  'l_barton_light_rum': '0',
#  'l_barton_long_island_iced_tea': '0',
#  'l_barton_naturals_vodka': '0',
#  'l_barton_vodka': '6',
#  'l_barton_vodka_mini': '0',
#  'l_barton_vodka_pet': '0',
#  'l_basil_hayden': '0',
#  'l_basil_hayden_10yr': '0',
#  'l_basil_hayden_8yr': '0',
#  'l_basil_hayden_bourbon': '0',
#  'l_basil_hayden_dark_rye': '0',
#  'l_basil_hayden_malted_rye': '0',
#  'l_basil_hayden_red_wine_cask_finish': '0',
#  'l_basil_hayden_subtle_smoke': '0',
#  'l_basil_hayden_toast': '2',
#  'l_batavia_arrack_van_oosten': '0',
#  'l_bauchant_orange_liqueur': '0',
#  'l_beach_bonfire_cinnamon_whiskey': '0',
#  'l_beach_island_coconut_whiskey': '0',
#  'l_beams_8_star_bl_whiskey': '0',
#  'l_bearface_7yr_triple_oak': '0',
#  'l_beefeater_gin': '0',
#  'l_belle_de_brillet': '0',
#  'l_bellissimo_limoncello': '0',
#  'l_beluga_gold_line_vodka': '0',
#  'l_beluga_noble_vodka': '0',
#  'l_belvedere_pure': '0',
#  'l_ben_holladay_6yr_mo_bourbon': '0',
#  'l_ben_holladay_rickhouse_proof_bourbon_whiskey': '0',
#  'l_benchmark_bonded': '0',
#  'l_benchmark_egg_nog': '0',
#  'l_benchmark_full_proof': '1',
#  'l_benchmark_old_no_8': '0',
#  'l_benchmark_single_barrel': '0',
#  'l_benchmark_small_batch': '0',
#  'l_benchmark_top_floor': '0',
#  'l_benriach_10yr_smoky': '0',
#  'l_benriach_12_year_smoky': '0',
#  'l_benriach_12yr': '0',
#  'l_benromach_10yr': '0',
#  'l_benromach_15yr': '0',
#  'l_benromach_21yr': '0',
#  'l_berentzen_apple': '0',
#  'l_berentzen_pear': '0',
#  'l_bernheim_original_wheat_whiskey': '0',
#  'l_betini_lemon_drop': '0',
#  'l_betini_margarita': '0',
#  'l_betini_pink_cranberry': '0',
#  'l_betini_tropical_sunset': '0',
#  'l_bib_tucker_double_char_bourbon': '0',
#  'l_bib_tucker_small_batch_bourbon_aged_6yr': '0',
#  'l_big_house_bourbon': '0',
#  'l_bigallet_china_china': '0',
#  'l_bigallet_thym': '0',
#  'l_bird_dog_apple': '0',
#  'l_bird_dog_apple_mini': '0',
#  'l_bird_dog_black_cherry': '0',
#  'l_bird_dog_black_cherry_mini': '0',
#  'l_bird_dog_black_espresso': '0',
#  'l_bird_dog_black_espresso_mini': '0',
#  'l_bird_dog_blackberry': '6',
#  'l_bird_dog_blackberry_mini': '1',
#  'l_bird_dog_candy_cane': '0',
#  'l_bird_dog_candy_cane_mini': '0',
#  'l_bird_dog_gingerbread': '0',
#  'l_bird_dog_honey_flavored_whiskey': '0',
#  'l_bird_dog_honey_flavored_whiskey_mini': '0',
#  'l_bird_dog_hot_cinnamon': '0',
#  'l_bird_dog_jalapeno_honey': '0',
#  'l_bird_dog_maple': '0',
#  'l_bird_dog_mesquite_brown_sugar': '0',
#  'l_bird_dog_mesquite_brown_sugar_mini': '0',
#  'l_bird_dog_peach': '0',
#  'l_bird_dog_peach_mini': '1',
#  'l_bird_dog_peach_pet': '0',
#  'l_bird_dog_peanut_butter': '0',
#  'l_bird_dog_peanut_butter_flavored_whiskey_mini': '0',
#  'l_bird_dog_pumpkin_spice': '0',
#  'l_bird_dog_ruby_red_grapefruit': '0',
#  'l_bird_dog_salted_caramel': '0',
#  'l_bird_dog_salted_caramel_flavored_whiskey_mini': '0',
#  'l_bird_dog_smores': '0',
#  'l_bird_dog_spiced': '0',
#  'l_bird_dog_strawberry': '0',
#  'l_bird_dog_strawberry_mini': '0',
#  'l_birdie_juice_old_fashioned_buy_the_barrel': '0',
#  'l_birthday_cake_sippin_cream': '0',
#  'l_bison_ridge_3_year': '0',
#  'l_bistra_apricot_brandy': '0',
#  'l_bistra_slivovitz_plum_brandy': '0',
#  'l_bitter_bianca': '0',
#  'l_black_dog_triple_gold_reserve_scotch_whisky': '0',
#  'l_black_saddle_bourbon': '0',
#  'l_black_tie_bourbon': '0',
#  'l_black_velvet': '27',
#  'l_black_velvet_apple': '0',
#  'l_black_velvet_apple_mini': '0',
#  'l_black_velvet_mini': '0',
#  'l_black_velvet_peach_canadian_whiskey': '6',
#  'l_black_velvet_peach_canadian_whiskey_mini': '0',
#  'l_black_velvet_pet': '0',
#  'l_black_velvet_reserve': '18',
#  'l_black_velvet_toasted_caramel': '0',
#  'l_blackened_cask_strength_blended_whiskey_vol_4': '0',
#  'l_blackened_whiskey': '0',
#  'l_blackened_x_rabbit_hole': '0',
#  'l_blackheart_premium_spiced_rum': '0',
#  'l_blackwell_rum': '0',
#  'l_blade_bow': '0',
#  'l_bladnoch_11_yo_single_malt_scotch_whisky': '0',
#  'l_bladnoch_vinaya_nas_single_malt_scotch_whisky': '0',
#  'l_blanton_gold_bourbon_buy_the_barrel': '0',
#  'l_blantons_bourbon': '6',
#  'l_blantons_buy_the_barrel': '0',
#  'l_blantons_gold_bourbon': '0',
#  'l_blantons_straight_from_the_barrel_bourbon': '0',
#  'l_blood_oath_pact_10': '0',
#  'l_blood_oath_pact_no_9': '0',
#  'l_bloody_butcher_bourbon': '0',
#  'l_bloom_gin': '0',
#  'l_blue_chair_bay_banana_rum': '0',
#  'l_blue_chair_bay_banana_rum_cream': '0',
#  'l_blue_chair_bay_coconut_rum': '0',
#  'l_blue_chair_bay_coconut_rum_2023_commemorative_wrap': '0',
#  'l_blue_chair_bay_key_lime_rum_cream': '0',
#  'l_blue_chair_bay_lime_rum': '0',
#  'l_blue_chair_bay_mango_rum_cream': '0',
#  'l_blue_chair_bay_mocha_cream': '0',
#  'l_blue_chair_bay_pineapple_rum_cream': '0',
#  'l_blue_chair_bay_spiced_rum': '0',
#  'l_blue_chair_bay_vanilla_rum': '0',
#  'l_blue_chair_bay_white_rum': '0',
#  'l_blue_dream': '0',
#  'l_blue_ice_american_huckleberry_vodka': '0',
#  'l_blue_ice_american_potato_vodka': '0',
#  'l_blue_ice_huckleberry_lemonade_vodka_cocktail': '0',
#  'l_blue_ox_gin': '0',
#  'l_blue_ox_silver_rum': '0',
#  'l_blue_ox_vodka': '0',
#  'l_blue_ox_vodka_mini': '0',
#  'l_blue_ox_vodka_pet': '0',
#  'l_blue_run_reflection_95_proof_bourbon': '0',
#  'l_boann_maderia_cask_single': '0',
#  'l_boann_masala_single_pot_still': '0',
#  'l_boann_px_cask_single_pot_still': '0',
#  'l_bobbys_scheidam_gin': '0',
#  'l_bodalen_bourbon': '0',
#  'l_bols_blue_curacao': '0',
#  'l_bols_cocktails_azul_margarita': '0',
#  'l_bols_cocktails_espresso_martini': '0',
#  'l_bols_cocktails_red_light_negroni': '0',
#  'l_bols_cocktails_very_old_fashioned': '0',
#  'l_bols_genever_barrel_aged': '0',
#  'l_bols_original_genever': '0',
#  'l_bols_triple_sec_30prf': '0',
#  'l_bombay_bramble': '0',
#  'l_bombay_dry_gin': '0',
#  'l_bombay_sapphire_gift_tin': '0',
#  'l_bombay_sapphire_gin': '0',
#  'l_bombay_sapphire_premier_cru': '0',
#  'l_boodles_british_gin_london_dry': '0',
#  'l_bookers_bourbon': '0',
#  'l_booths_finest_old_gin': '0',
#  'l_boreal_cedar_gin': '0',
#  'l_bosscal_joven_mezcal': '0',
#  'l_bottega_pistaschio_liqueur': '0',
#  'l_boukman_botanical_rhum': '0',
#  'l_bowling_burch_gin': '0',
#  'l_bowman_brothers_bourbon': '0',
#  'l_bowmore_scotch_12yr': '0',
#  'l_bozal_barril_mezcal_reserva': '0',
#  'l_bozal_cempasuchil_mezcal': '0',
#  'l_bozal_cenizo_mezcal': '0',
#  'l_bozal_cuishe_mezcal': '0',
#  'l_bozal_ensamble_mezcal': '0',
#  'l_bozal_iberico_mezcal': '0',
#  'l_bozal_madrecuishe': '0',
#  'l_bozal_pechuga_mezcal': '0',
#  'l_bozal_sacatoro_single_maguey': '0',
#  'l_bozal_tepezate_single_maugay': '0',
#  'l_bozal_tobala_reserva_mezcal': '0',
#  'l_bozal_tobasiche_mezcal': '0',
#  'l_bp_1792_bib_bourbon_ksbw': '0',
#  'l_bp_bulleit_single_barrel': '4',
#  'l_bp_codigo_1530_tequila_anejo_cognac': '0',
#  'l_bp_crown_royal_hand_select_barrel': '1',
#  'l_bp_eagle_rare_sp_bourbon': '0',
#  'l_bp_elijah_craig_private_barrel_barrel_proof': '0',
#  'l_bp_ezra_brooks_cask_strength': '0',
#  'l_bp_ezra_brooks_stave_finish_collection': '0',
#  'l_bp_george_dickel_15_yr_single_barrel': '0',
#  'l_bp_george_dickel_single_barrel_9yr': '0',
#  'l_bp_horse_soldier_private_barrel_bourbon': '0',
#  'l_bp_jack_daniels_single_barrel_personal_collection': '0',
#  'l_bp_keepers_heart_irish_american_finished_in_a_stout_barrel': '0',
#  'l_bp_knob_creek_rye_single_barrel': '0',
#  'l_bp_knob_creek_single_barrel': '0',
#  'l_bp_koval_single_barrel_bourbon_whiskey': '0',
#  'l_bp_koval_single_barrel_whiskey_rye_bottled_in_bond': '0',
#  'l_bp_last_drop_1971_blended_whisky_w_50ml': '0',
#  'l_bp_maestro_dobel_anejo_tequila_f1': '0',
#  'l_bp_makers_mark_private_select_barrel_buy': '0',
#  'l_bp_patron_reposado_barrel_select': '0',
#  'l_bp_rabbit_hole_cavehill_barrel': '0',
#  'l_bp_rabbit_hole_heigold_bourbon_whiskey_barrel': '0',
#  'l_bp_rebel_cask_strength': '0',
#  'l_bp_rebel_stave_finish_collection': '0',
#  'l_bp_remus_single_barrel': '0',
#  'l_bp_templeton_rye_single_barrel_selection': '0',
#  'l_bp_town_branch_rye_single_barrel_reserve': '0',
#  'l_bp_town_branch_single_barrel_reserve_bourbon': '0',
#  'l_bp_whistlepig_18_year_old_rye_single_barrel': '0',
#  'l_bp_wilderness_trail_high_rye_bourbon_family_reserve': '0',
#  'l_bp_wilderness_trail_rye_whiskey_family_reserve': '0',
#  'l_bp_wilderness_trail_wheated_bourbon_family_reserve': '0',
#  'l_branson_xo': '0',
#  'l_breaking_entering_american_whiskey': '0',
#  'l_breckenridge_bourbon': '0',
#  'l_breckenridge_chili_chile_vodka': '0',
#  'l_breckenridge_px_cask_finish': '0',
#  'l_breckenridge_vodka': '0',
#  'l_breckenridge_whiskey_port_cask_finish': '0',
#  'l_brinley_gold_shipwreck_spiced_rum': '0',
#  'l_brinley_gold_shipwreck_vanilla_rum': '0',
#  'l_brinley_shipwreck_coconut_rum': '0',
#  'l_british_navy_pussers_rum': '0',
#  'l_brockmans_gin': '0',
#  'l_brodys_classic_mai_tai_rum_cocktail': '0',
#  'l_brodys_craft_cocktails_black_orchid_vodka': '0',
#  'l_brodys_craft_cocktails_minted_mule_vodka': '0',
#  'l_brodys_leading_role_bourbon_cocktail': '0',
#  'l_brodys_peach_cosmo_vodka_cocktail': '0',
#  'l_broken_shed_vodka': '0',
#  'l_brokers_gin': '0',
#  'l_brotherhood_bourbon': '0',
#  'l_brothers_bond_american_blended_rye_whiskey': '0',
#  'l_brothers_bond_cask_strength_whiskey': '0',
#  'l_brothers_bond_straight_bourbon_whiskey': '0',
#  'l_brown_jug_bourbon_cream': '0',
#  'l_brown_sugar_blend': '0',
#  'l_brown_sugar_blend_70prf': '0',
#  'l_brugal_1888_gran_reserva': '0',
#  'l_brugal_xv_rum': '0',
#  'l_brugal_xv_rum_disco': '0',
#  'l_bruichladdich_islay_barley': '0',
#  'l_bruichladdich_pc_islay_barley_2012': '0',
#  'l_bruichladdich_scottish_barley': '0',
#  'l_bubbas_burnt_sugar_whiskey': '0',
#  'l_bubbas_marshmallow_chocolate_whiskey': '0',
#  'l_buchanan_deluxe_12yr': '0',
#  'l_buchanan_red_seal': '0',
#  'l_buchanan_special_reserve_18yr': '0',
#  'l_buchanans_deluxe_w_2_salsa_bowls': '0',
#  'l_buchanans_pineapple': '0',
#  'l_buffalo_trace_bourbon': '12',
#  'l_buffalo_trace_bourbon_buy_the_barrel': '0',
#  'l_buffalo_trace_bourbon_cream': '0',
#  'l_buffalo_trace_bourbon_cream_mini': '0',
#  'l_buffalo_trace_sazerac_barrel_select_buy_the_barrel': '0',
#  'l_builders_botanical_gin': '0',
#  'l_bulldog_gin': '0',
#  'l_bulleit_95_rye': '0',
#  'l_bulleit_bourbon': '0',
#  'l_bulleit_bourbon_10yr': '0',
#  'l_bulleit_bourbon_barrel_strength': '0',
#  'l_bulleit_bourbon_mini': '0',
#  'l_bulleit_bourbon_whiskey_w_mug': '0',
#  'l_bulleit_manhattan_cocktail': '0',
#  'l_bulleit_old_fashioned_cocktail': '0',
#  'l_bulleit_rye_10_year': '0',
#  'l_bulleit_rye_12_yr': '0',
#  'l_bulleit_single_barrel': '0',
#  'l_bulleit_single_barrel_buy_the_barrel': '0',
#  'l_bulleit_single_malt_whiskey': '0',
#  'l_bullhorn_whiskey': '0',
#  'l_bumbu_creme': '0',
#  'l_bumbu_rum': '0',
#  'l_bumbu_xo': '0',
#  'l_bumbu_xo_vap_with_rocks_glasses': '0',
#  'l_bunnahabhain_12yr': '0',
#  'l_bunnahabhain_14_year_old_ruby_port': '0',
#  'l_bunnahabhain_stiuireadair': '0',
#  'l_bunnahabhain_toiteach_a_dha': '0',
#  'l_burnetts_blue_raspberry': '0',
#  'l_burnetts_blueberry': '0',
#  'l_burnetts_cherry': '0',
#  'l_burnetts_citrus': '0',
#  'l_burnetts_gin_london_dry': '0',
#  'l_burnetts_grape': '0',
#  'l_burnetts_grape_disco': '0',
#  'l_burnetts_mango_pineapple': '0',
#  'l_burnetts_pineapple': '0',
#  'l_burnetts_raspberry': '0',
#  'l_burnetts_strawberry_banana': '0',
#  'l_burnetts_sweet_tea': '0',
#  'l_burnetts_vodka_100prf': '0',
#  'l_burnetts_vodka_80prf': '0',
#  'l_burnetts_vodka_traveler': '0',
#  'l_burnetts_watermelon': '0',
#  'l_bushmills_10yr_irish_whiskey': '0',
#  'l_bushmills_12yr_single_malt_irish_whiskey': '0',
#  'l_bushmills_black_bush_irish_whiskey': '0',
#  'l_bushmills_irish_whiskey': '0',
#  'l_bushmills_peaky_blinders': '0',
#  'l_bushmills_w_golf_flask': '0',
#  'l_bushmills_with_rocks_glass_vap': '0',
#  'l_butchers_block_vodka': '0',
#  'l_buzzards_roost_barrel_strength_rye_whiskey': '0',
#  'l_buzzards_roost_barrel_strength_straight_bourbon': '0',
#  'l_buzzards_roost_char_1_rye_whiskey': '0',
#  'l_buzzards_roost_char_1_straight_bourbon_whiskey': '0',
#  'l_buzzards_roost_cigar_rye_straight_rye_whiskey': '0',
#  'l_buzzards_roost_toasted_american_oak_straight_bourbon': '0',
#  'l_buzzards_roost_toasted_barrel_single_straight_rye_whiskey': '0',
#  'l_buzzballz_biggies_chili_mango': '0',
#  'l_buzzballz_biggies_chocolate_tease': '0',
#  'l_buzzballz_biggies_strawberry_rita': '0',
#  'l_buzzballz_biggies_tequila_rita': '0',
#  'l_c_crets_whiskey': '0',
#  'l_cabin_still_str_bourbon': '0',
#  'l_cabo_wabo_anejo': '0',
#  'l_cabo_wabo_blanco': '6',
#  'l_cabo_wabo_reposado': '6',
#  'l_caffe_lolita_coffee_liqueur': '0',
#  'l_caliber_canadian_whiskey': '0',
#  'l_caliber_citrus_vodka': '0',
#  'l_caliber_gin': '0',
#  'l_caliber_silver_rum': '0',
#  'l_caliber_spiced_rum': '0',
#  'l_caliber_vodka': '0',
#  'l_calico_jack_cherry': '0',
#  'l_calico_jack_cherry_rum': '0',
#  'l_calico_jack_coconut_rum': '0',
#  'l_calico_jack_pineapple_coconut_rum': '0',
#  'l_calico_jack_spiced_rum': '0',
#  'l_calico_jack_whipped': '0',
#  'l_calirosa_anejo': '0',
#  'l_calirosa_rosa_blanco': '0',
#  'l_calumet_farm_10yr_bourbon': '0',
#  'l_calumet_farm_16_yr': '0',
#  'l_calumet_farm_8yr': '0',
#  'l_calypso_silver_rum': '0',
#  'l_calypso_spiced_rum': '0',
#  'l_campari_gift_set_with_mixing_spoon': '0',
#  'l_campari_italian_aperitivo': '0',
#  'l_campari_negroni_vap': '0',
#  'l_campo_bravo_plata_tequila': '0',
#  'l_canadian_club_44yr_chronicles': '0',
#  'l_canadian_club_apple': '0',
#  'l_canadian_club_small_batch_classic': '0',
#  'l_canadian_club_whisky': '0',
#  'l_canadian_club_whisky_mini': '0',
#  'l_canadian_club_whisky_pet': '0',
#  'l_canadian_hunter_rye': '0',
#  'l_canadian_ltd_whisky': '12',
#  'l_canadian_ltd_whisky_pet': '0',
#  'l_canadian_mist': '0',
#  'l_canadian_mist_whisky': '0',
#  'l_canadian_mist_whisky_pet': '0',
#  'l_canadian_reserve_whisky': '0',
#  'l_cancion_anejo_tequila': '0',
#  'l_cancion_blanco_tequila': '0',
#  'l_cancion_reposado_tequila': '0',
#  'l_candy_corn_whiskey': '0',
#  'l_cantera_negra_anejo': '0',
#  'l_cantera_negra_cafe': '0',
#  'l_cantera_negra_reposado': '0',
#  'l_cantera_negra_silver_tequila': '0',
#  'l_cantera_negra_tequila_reposado': '0',
#  'l_cantera_negra_tequila_silver': '0',
#  'l_caol_ila_12yr': '0',
#  'l_cape_horn_blanco': '0',
#  'l_cape_horn_reposado': '0',
#  'l_capel_pisco_reservado': '0',
#  'l_capel_pisco_reservado_use_code_978334': '0',
#  'l_captain_morgan_100prf_spiced_rum': '2',
#  'l_captain_morgan_coconut': '0',
#  'l_captain_morgan_long_island_iced_tea': '0',
#  'l_captain_morgan_mai_tai_rtd': '0',
#  'l_captain_morgan_original_spiced': '0',
#  'l_captain_morgan_original_spiced_barrel': '18',
#  'l_captain_morgan_original_spiced_mini': '1',
#  'l_captain_morgan_original_spiced_pet': '0',
#  'l_captain_morgan_osr_1_75l_w_2x50ml_cm_100_proof': '0',
#  'l_captain_morgan_osr_w_nfl_tin_cup': '0',
#  'l_captain_morgan_pineapple': '0',
#  'l_captain_morgan_private_stock': '3',
#  'l_captain_morgan_silver_spiced': '0',
#  'l_captain_morgan_sliced_apple': '0',
#  'l_captain_morgan_tropical_punch_rtd': '0',
#  'l_captain_morgan_white': '0',
#  'l_captain_morgan_white_pet': '0',
#  'l_caravedo_acholado': '0',
#  'l_caravedo_acholado_use_code_951580': '0',
#  'l_caravedo_mosto_verde_pisco': '0',
#  'l_caravedo_puro_quebranta': '0',
#  'l_caravedo_puro_quebranta_use_code_951303': '0',
#  'l_caravedo_puro_torontel': '0',
#  'l_caravedo_puro_torontel_use_code_951553': '0',
#  'l_caravella_limoncello': '0',
#  'l_cardenal_mendoza_brandy': '0',
#  'l_caribou_crossing': '1',
#  'l_caribou_crossing_buy_the_barrel': '0',
#  'l_carolans_holiday_vap': '0',
#  'l_carolans_irish_cream': '0',
#  'l_carolans_peanut_butter': '0',
#  'l_carolans_salted_caramel': '0',
#  'l_carpano_botanic_bitter': '0',
#  'l_casa_amor_anejo': '0',
#  'l_casa_amor_blanco': '0',
#  'l_casa_amor_extra_anejo': '0',
#  'l_casa_amor_reposado': '0',
#  'l_casa_dragones_375ml_family_gift_pack': '0',
#  'l_casa_dragones_anejo': '0',
#  'l_casa_dragones_blanco': '0',
#  'l_casa_noble_crystal': '0',
#  'l_casa_noble_marques_de_tequila': '0',
#  'l_casa_noble_reposado': '0',
#  'l_casamigas_jalapeno_tequila': '0',
#  'l_casamigos_anejo': '0',
#  'l_casamigos_anejo_mini': '0',
#  'l_casamigos_anejo_w_mason_jar_juicer': '0',
#  'l_casamigos_anejo_w_4_coasters': '0',
#  'l_casamigos_blanco': '0',
#  'l_casamigos_blanco_mini': '0',
#  'l_casamigos_blanco_w_mason_jar_juicer': '0',
#  'l_casamigos_cristalino': '0',
#  'l_casamigos_mezcal': '0',
#  'l_casamigos_mezcal_joven': '0',
#  'l_casamigos_mezcal_w_mason_jar_juicer': '0',
#  'l_casamigos_mezcal_w_4_coasters': '0',
#  'l_casamigos_reposado': '0',
#  'l_casamigos_reposado_mini': '0',
#  'l_casamigos_reposado_w_mason_jar_juicer': '0',
#  'l_cashel_irish_cream': '0',
#  'l_cask_strength_private_barrel_bourbon': '0',
#  'l_castillo_silver_rum': '0',
#  'l_cava_de_oro_rose_gold_tequila': '0',
#  'l_cazadores_anejo': '0',
#  'l_cazadores_blanco': '0',
#  'l_cazadores_cafe': '0',
#  'l_cazadores_paloma_rts': '0',
#  'l_cazadores_reposado': '0',
#  'l_cazadores_reposado_w_jarritos_pack': '0',
#  'l_cazcanes_anejo_tequila_no_7': '0',
#  'l_cazcanes_blanco_tequila_no_9': '0',
#  'l_cazcanes_blanco_tequila_no_7': '0',
#  'l_cazcanes_blanco_tequila_no_10_still_strength': '0',
#  'l_cazcanes_reposado_tequila_no_7': '0',
#  'l_ccrets_island_mix': '0',
#  'l_cedar_ridge_amontillado_sherry_finished_bourbon': '0',
#  'l_cedar_ridge_barrel_proof': '0',
#  'l_cedar_ridge_bottled_in_bond_bourbon': '0',
#  'l_cedar_ridge_bottled_in_bond_rye_whiskey': '0',
#  'l_cedar_ridge_bourbon': '0',
#  'l_cedar_ridge_bourbon_single_barrel_collection_s_b_c': '0',
#  'l_cedar_ridge_dark_rum': '0',
#  'l_cedar_ridge_double_barrel_bourbon_whiskey': '0',
#  'l_cedar_ridge_double_barrel_straight_rye_whiskey': '0',
#  'l_cedar_ridge_fruit_brandy': '0',
#  'l_cedar_ridge_lost_pirate_port_finish_rum': '0',
#  'l_cedar_ridge_malted_rye': '0',
#  'l_cedar_ridge_port_cask_finished_bourbon': '0',
#  'l_cedar_ridge_port_cask_finished_straight_rye_whiskey': '0',
#  'l_cedar_ridge_private_barrel_straight_rye_whiskey': '0',
#  'l_cedar_ridge_private_cask_iowa_bourbon_selection_barrel_buy': '0',
#  'l_cedar_ridge_quintessential_american_single_malt': '0',
#  'l_cedar_ridge_single_barrel_the_quintessential_single_malt': '0',
#  'l_cedar_ridge_single_malt_single_barrel_select': '0',
#  'l_cedar_ridge_sir_maple_bourbon_whiskey': '0',
#  'l_cedar_ridge_wheat_whiskey': '0',
#  'l_celtic_honey_beekeepers_blend': '0',
#  'l_century_farms_unaged_high_proof_corn_whiskey': '0',
#  'l_century_farms_american_classic': '0',
#  'l_century_farms_american_classic_personalized': '0',
#  'l_century_farms_bourbon_personalized': '0',
#  'l_century_farms_open_gate_sweet_tea_vodka': '0',
#  'l_century_farms_prairie_states_corn_whiskey_aged_on_oak_chips': '0',
#  'l_century_farms_prairie_states_unaged_high_proof_corn_whiskey': '0',
#  'l_century_farms_single_barrel_straight_bourbon_whiskey': '0',
#  'l_century_farms_single_barrel_straight_corn_whiskey': '0',
#  'l_century_farms_sweet_tea_vodka': '0',
#  'l_century_farms_unaged_high_proof_corn_whiskey_1': '0',
#  'l_century_farms_vodka': '0',
#  'l_ch_chi_s_peach_margarita': '0',
#  'l_chairmans_reserve_forgotten_casks': '0',
#  'l_chairmans_reserve_spiced_rum': '0',
#  'l_chambord_liqueur_minis': '0',
#  'l_chambord_liqueur_royale_de_france': '0',
#  'l_chamucos_blanco': '0',
#  'l_chamucos_diablo_blanco': '0',
#  'l_chamucos_tequila_anejo': '0',
#  'l_chamucos_tequila_blanco': '0',
#  'l_chamucos_tequila_reposado': '0',
#  'l_chareau_aloe_liqueur': '0',
#  'l_charles_baur_fine_d_alsace': '0',
#  'l_charles_baur_fine_d_alsace_disco': '0',
#  'l_charles_baur_poire_william': '0',
#  'l_charter_french_oak': '0',
#  'l_chi_chi_s_chocolate_malt': '0',
#  'l_chi_chi_s_churro': '0',
#  'l_chi_chi_s_gold_margarita': '0',
#  'l_chi_chi_s_long_island_iced_tea': '0',
#  'l_chi_chi_s_mai_tai': '0',
#  'l_chi_chi_s_mango_margarita': '0',
#  'l_chi_chi_s_margarita': '0',
#  'l_chi_chi_s_mexican_mudslide': '0',
#  'l_chi_chi_s_orange_cream': '0',
#  'l_chi_chi_s_pina_colada': '0',
#  'l_chi_chi_s_pineapple_margarita': '0',
#  'l_chi_chi_s_pink_lemonade_margarita': '0',
#  'l_chi_chi_s_ruby_red_margarita': '0',
#  'l_chi_chi_s_skinny_margarita': '0',
#  'l_chi_chi_s_strawberry_daquiri': '0',
#  'l_chi_chi_s_strawberry_margarita': '0',
#  'l_chi_chi_s_white_russian': '0',
#  'l_chicken_cock_double_oak_kentucky_whiskey': '0',
#  'l_chicken_cock_kentucky_straight_bourbon': '0',
#  'l_chicken_cock_kentucky_straight_rye': '0',
#  'l_chicken_cock_private_cask_buy_the_barrel': '0',
#  'l_chicken_cock_reserve_cask_gg_buy_the_barrel': '0',
#  'l_chicken_cock_small_batch_kentucky_straight_bourbon': '0',
#  'l_chila_coffee_liqueur': '0',
#  'l_chinola_mango_liqueur_master': '0',
#  'l_chinola_passion_fruit_liqueur': '0',
#  'l_chivas_12yr_w_cocktail_caddy_and_shaker': '0',
#  'l_chivas_regal_12yr': '0',
#  'l_chivas_regal_18yr': '0',
#  'l_chivas_xv': '0',
#  'l_chocolate_coffee_sippin_cream': '0',
#  'l_chopin_vodka': '0',
#  'l_chopin_vodka_family_reserve': '0',
#  'l_choya_golden_ume_fruits': '0',
#  'l_choya_uji_green_tea_umeshu': '0',
#  'l_choya_yuzu_liqueur': '0',
#  'l_christian_bros_apple': '0',
#  'l_christian_bros_brandy': '0',
#  'l_christian_bros_brandy_pet': '0',
#  'l_christian_bros_brandy_round': '0',
#  'l_christian_bros_brandy_square': '0',
#  'l_christian_bros_frost_white_brandy': '0',
#  'l_christian_bros_grand_reserve_vsop': '0',
#  'l_christian_bros_holiday_nog': '0',
#  'l_christian_bros_honey': '0',
#  'l_christian_bros_peach': '0',
#  'l_chum_churum_original_soju': '0',
#  'l_cierto_anejo_tequila_private_collection': '0',
#  'l_cierto_blanco_tequila_private_collection': '0',
#  'l_cierto_reposado_tequila_private_collection': '0',
#  'l_cimarron_tequila_blanco': '0',
#  'l_cincoro_anejo_tequila': '0',
#  'l_cincoro_blanco_tequila': '0',
#  ...}

# %% [markdown]
# ## 1-2. convert_X_raw_to_array()

# %%
X = convert_X_raw_to_array(X_raw)

# %%
X.shape
# Out:
# (23183, 4533)

# %% [markdown]
# ## 1-3. train_test_valid_split()

# %%
X_train, X_test, X_valid, y_train, y_test, y_valid = train_test_valid_split(X, y)

# %%
print(X_train.shape)
print(y_train.shape[0])
# Out:
# (16199, 4533)
# 16199

# %%
print(X_test.shape)
print(y_test.shape[0])
# Out:
# (3549, 4533)
# 3549

# %%
print(X_valid.shape)
print(y_valid.shape[0])
# Out:
# (3435, 4533)
# 3435

# %% [markdown]
# ## 1-4. add_ones()

# %%
X_ones = add_ones(X)

# %%
X_ones[0]
# Out:
# array(['1.0', '0', '0', ..., '0', '0', '0'], shape=(4534,), dtype='<U32')

# %% [markdown]
# ## 1-5. ols()

# %%
beta_ols = ols(X_train, y_train)

# %%
beta_ols
# Out:
# array([-160.89194834,   -3.33339453,  -56.67157546, ...,    0.42340152,
#           3.21451152,    0.56079671], shape=(4299,))

# %% [markdown]
# # 2. Redge Regression

# %% [markdown]
# ## 2-1. Training Data

# %%
X_train, y_train = recenter(X_train, y_train)
beta_hat_train = ridge(X_train, y_train, fLambda=1)

# %%
removed_cols, original_cols = get_removed_col_indices(X_train)
feat_list = list(X_raw[0].keys())
final_cols_train = remove_features(feat_list, removed_cols)
beta_hat_train_labeled = np.column_stack((final_cols_train, beta_ridge))
np.savetxt("beta_hat_train_labeled.csv", beta_ridge_labeled, fmt="%s", delimiter=",")

# %%
y_hat_train = predict(X_train, beta_hat_train)
mse_train = mean_squared_error(y_hat_train, y_train)
print('MSE in sample:', mse_train)
# Out:
# MSE in sample: 264841.8511735275

# %% [markdown]
# ## 2-2. Testing Data

# %%
X_test, y_test = recenter(X_test, y_test)
beta_hat_test = ridge(X_test, y_test, fLambda=1)

# %%
removed_cols, original_cols = get_removed_col_indices(X_test)
feat_list = list(X_raw[0].keys())
final_cols_test = remove_features(feat_list, removed_cols)
beta_hat_test_labeled = np.column_stack((final_cols_test, beta_hat_test))
np.savetxt("beta_hat_test_labeled.csv", beta_hat_test_labeled, fmt="%s", delimiter=",")

# %%
y_hat_test = predict(X_test, beta_hat_test)
mse_test = mean_squared_error(y_hat_test, y_test)
print('MSE out sample:', mse_test)
# Out:
# MSE out sample: 19563.101172821785
